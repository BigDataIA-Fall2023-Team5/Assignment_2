# %% [markdown]
# # Embedding Wikipedia articles for search
#
# This notebook shows how we prepared a dataset of Wikipedia articles for search, used in [Question_answering_using_embeddings.ipynb](Question_answering_using_embeddings.ipynb).
#
# Procedure:
#
# 0. Prerequisites: Import libraries, set API key (if needed)
# 1. Collect: We download a few hundred Wikipedia articles about the 2022 Olympics
# 2. Chunk: Documents are split into short, semi-self-contained sections to be embedded
# 3. Embed: Each section is embedded with the OpenAI API
# 4. Store: Embeddings are saved in a CSV file (for large datasets, use a vector database)

# %% [markdown]
# ## 0. Prerequisites
#
# ### Import libraries

# %%
# imports
import mwclient  # for downloading example Wikipedia articles
import mwparserfromhell  # for splitting Wikipedia articles into sections
import openai  # for generating embeddings
import pandas as pd  # for DataFrames to store article sections and embeddings
import re  # for cutting <ref> links out of Wikipedia articles
import tiktoken  # for counting tokens

# %% [markdown]
# Install any missing libraries with `pip install` in your terminal. E.g.,
#
# ```zsh
# pip install openai
# ```
#
# (You can also do this in a notebook cell with `!pip install openai`.)
#
# If you install any libraries, be sure to restart the notebook kernel.

# %% [markdown]
# ### Set API key (if needed)
#
# Note that the OpenAI library will try to read your API key from the `OPENAI_API_KEY` environment variable. If you haven't already, set this environment variable by following [these instructions](https://help.openai.com/en/articles/5112595-best-practices-for-api-key-safety).

# %%
import os
import getpass
import openai
os.environ['OPENAI_API_KEY'] = getpass.getpass()  #Passkey: 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
openai.api_key = os.getenv("OPENAI_API_KEY")

# %% [markdown]
# ## 1. Collect documents
#
# In this example, we'll download a few hundred Wikipedia articles related to the 2022 Winter Olympics.

# %%
df = pd.read_csv('form_qa.csv')

# %%
df
# Out:
#                Number                                        Description  \
# 0                   1  Application for registration or exemption from...
# 1                 1-A              Regulation A Offering Statement (PDF)
# 2                 1-E              Notification under Regulation E (PDF)
# 3                 1-K  Annual Reports and Special Financial Reports (...
# 4                 1-N  Form and amendments for notice of registration...
# ..                ...                                                ...
# 144    X-17A-5 Part I                         FOCUS Report, Part I (PDF)
# 145   X-17A-5 Part II           FOCUS Report, Part II Instructions (PDF)
# 146   X-17A-5 Part II                        FOCUS Report, Part II (PDF)
# 147  X-17A-5 Part IIA                        FOCUS Report Part IIa (PDF)
# 148  X-17A-5 Part IIA           FOCUS Report Part IIa Instructions (PDF)
#
#     Last_Updated SEC_Number  \
# 0      Feb. 1999    SEC1935
# 1     Sept. 2021     SEC486
# 2      Aug. 2001    SEC1807
# 3     Sept. 2021    SEC2913
# 4      Dec. 2013    SEC2568
# ..           ...        ...
# 144       Apr-03    SEC1705
# 145    Oct. 2021   SEC1695A
# 146    Oct. 2021    SEC1695
# 147    Nov. 2018    SEC1696
# 148    Nov. 2018   SEC1696A
#
#                                                  Topic  \
# 0                        Self-Regulatory Organizations
# 1             Securities Act of 1933, Small Businesses
# 2    Investment Company Act of 1940, Small Business...
# 3             Securities Act of 1933, Small Businesses
# 4    Securities Exchange Act of 1934, Self-Regulato...
# ..                                                 ...
# 144       Security-Based Swap Entities, Broker-Dealers
# 145       Security-Based Swap Entities, Broker-Dealers
# 146       Security-Based Swap Entities, Broker-Dealers
# 147       Security-Based Swap Entities, Broker-Dealers
# 148       Security-Based Swap Entities, Broker-Dealers
#
#                                               PDF_Link  \
# 0                https://www.sec.gov/files/form1-e.pdf
# 1                https://www.sec.gov/files/form1-k.pdf
# 2                https://www.sec.gov/files/form1-n.pdf
# 3               https://www.sec.gov/files/form1-sa.pdf
# 4                https://www.sec.gov/files/form1-u.pdf
# ..                                                 ...
# 144  https://www.sec.gov/files/formx-17a-5_2c-instr...
# 145       https://www.sec.gov/files/formx-17a-5_2c.pdf
# 146        https://www.sec.gov/files/formx-17a-5_3.pdf
# 147   https://www.sec.gov/files/formx-17a-5_schedi.pdf
# 148         https://www.sec.gov/files/formx-17f-1a.pdf
#
#                                       pyPDF_extraction  tokens  \
# 0    You may not send a completed printout of this ...    1581
# 1    UNITED STATES SECURITIES AND EXCHANGE COMMISSI...    2000
# 2    OMB APPROVAL OMB Number 3235 0554 Expires Febr...    2000
# 3    UNITED STATES SECURITIES AND EXCHANGE COMMISSI...    2000
# 4    OMB APPROVAL OMB Number 3235 0722 Expires Dece...    2000
# ..                                                 ...     ...
# 144  UNITED STATES SECURITIES AND EXCHANGE COMMISSI...    1170
# 145  Form X 17A 5 FOCUS Report Part IIC Cover Page ...    2000
# 146  UNITED STATES SECURITIES AND EXCHANGE COMMISSI...     920
# 147  OMB APPROVAL OMB Number 3235 0123 Expires Octo...    2000
# 148  UNITED STATES SECURITIES AND EXCHANGE COMMISSI...     988
#
#                                              questions  \
# 0    1) What is the purpose of Form 1-E mentioned i...
# 1    1. What is the purpose of Form 1-K?\n2. What a...
# 2    1. What is the purpose of Form 1-N?\n\n2. How ...
# 3    1. What is the purpose of Form 1 SA?\n2. How o...
# 4    1. What is the purpose of Form 1-U?\n\n2. What...
# ..                                                 ...
# 144  1. Who is required to file Part IIC of the FOC...
# 145  1. How many types of entities can file the For...
# 146  1. What information is required to be included...
# 147                                                NaN
# 148  1. What is the purpose of Form X-17F-1A?\n2. W...
#
#                                                answers
# 0    1.The purpose of Form 1-E mentioned in the tex...
# 1    1.The purpose of Form 1-K is to provide an ann...
# 2    1.The purpose of Form 1-N is to serve as a not...
# 3    1.The purpose of Form 1 SA is to file semiannu...
# 4    1.The purpose of Form 1-U is to file a current...
# ..                                                 ...
# 144  1.Firms that are regulated by a prudential reg...
# 145  1.There are two types of entities that can fil...
# 146                                                  1
# 147                           1.I dont know the answer
# 148  1.The purpose of Form X-17F-1A is to report mi...
#
# [149 rows x 10 columns]

# %% [markdown]
# ## 2. Embed document chunks
#
# Now that we've split our library into shorter self-contained strings, we can compute embeddings for each.
#
# (For large embedding jobs, use a script like [api_request_parallel_processor.py](api_request_parallel_processor.py) to parallelize requests while throttling to stay under rate limits.)

# %%
extracted_text = df['pyPDF_extraction'].tolist()

# %%
# calculate embeddings
EMBEDDING_MODEL = "text-embedding-ada-002"  # OpenAI's best embeddings as of Apr 2023
BATCH_SIZE = 1000  # you can submit up to 2048 embedding inputs per request

embeddings = []
for batch_start in range(0, len(extracted_text), BATCH_SIZE):
    batch_end = batch_start + BATCH_SIZE
    batch = extracted_text[batch_start:batch_end]
    print(f"Batch {batch_start} to {batch_end-1}")
    response = openai.Embedding.create(model=EMBEDDING_MODEL, input=batch)
    for i, be in enumerate(response["data"]):
        assert i == be["index"]  # double check embeddings are in same order as input
    batch_embeddings = [e["embedding"] for e in response["data"]]
    embeddings.extend(batch_embeddings)

df1 = pd.DataFrame({"text": extracted_text, "embedding": embeddings})
# Out:
# Batch 0 to 999

# %%
df1
# Out:
#                                                   text  \
# 0    You may not send a completed printout of this ...
# 1    UNITED STATES SECURITIES AND EXCHANGE COMMISSI...
# 2    OMB APPROVAL OMB Number 3235 0554 Expires Febr...
# 3    UNITED STATES SECURITIES AND EXCHANGE COMMISSI...
# 4    OMB APPROVAL OMB Number 3235 0722 Expires Dece...
# ..                                                 ...
# 144  UNITED STATES SECURITIES AND EXCHANGE COMMISSI...
# 145  Form X 17A 5 FOCUS Report Part IIC Cover Page ...
# 146  UNITED STATES SECURITIES AND EXCHANGE COMMISSI...
# 147  OMB APPROVAL OMB Number 3235 0123 Expires Octo...
# 148  UNITED STATES SECURITIES AND EXCHANGE COMMISSI...
#
#                                              embedding
# 0    [-0.005231186281889677, -0.002754298970103264,...
# 1    [-0.012306703254580498, -0.0033481954596936703...
# 2    [-0.02113576978445053, -0.003132110694423318, ...
# 3    [-0.002609275048598647, -0.009246379137039185,...
# 4    [-0.020553508773446083, -0.009975481778383255,...
# ..                                                 ...
# 144  [-0.007044337224215269, -0.006628572475165129,...
# 145  [-0.0035341274924576283, 0.003870225977152586,...
# 146  [-0.003206119639798999, -0.0044323778711259365...
# 147  [-0.015941224992275238, -0.0038643358275294304...
# 148  [-0.00875669065862894, -0.0011045521823689342,...
#
# [149 rows x 2 columns]

# %% [markdown]
# ## 3. Store document chunks and embeddings
#
# Because this example only uses a few thousand strings, we'll store them in a CSV file.
#
# (For larger datasets, use a vector database, which will be more performant.)

# %%
# save document chunks and embeddings

SAVE_PATH = "form_embeddings.csv"

df1.to_csv(SAVE_PATH, index=False)
